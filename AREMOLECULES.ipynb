# %%
#%matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib.animation as anim
from matplotlib.animation import FuncAnimation
import numpy as np
import copy

# %%
def random_particules_v3(n):
    N=[]
    N.append(0)
    
    for i in range(n-1):
        i=i+1
        N.append(i)
    position={}
    typ= {}
    for i in range(n):
        x,y = np.random.random(),np.random.random()
        position[i]=(x,y)
        
        if np.random.rand()<=(1/3):
            typ[i] = 2
        elif np.random.rand()<=(1/3):
            typ[i] = 20
        else :
            typ[i] = 43
        
    return N,position,typ

# %%
def sum_tuple(a,b):
    return (a[0]+b[0],a[1]+b[1])

# %%
def mult_tuple(a,b):
    return (a[0]*b[0],a[1]*b[1])

# %%
def direction_v3(N,position,v):
    direction={}
    
    for i in range(len(N)):
        if np.random.rand()<0.25:
            direction[i]=(v,v)
            
        elif np.random.rand()<0.25:
            direction[i]=(-v,-v)
            
        elif np.random.rand()<0.25:
            direction[i]=(v,-v)
            
        else: 
            direction[i]=(-v,v)
        
        
        
    return direction

# %%
def update_particules_v3(N,position,direction):
    
    
    for i in N:
        position[i]= sum_tuple(position[i],direction[i])
        
    #REBOND    
    for i in N:
        (a,b)=position[i] 
        
        if a<= 0 and b<=0:
            a=0
            b=0
            position[i]=(a,b)
            direction[i]= mult_tuple(direction[i],(-1,-1))
            
        if a>= 1 and b>=1:
            a=1
            b=1
            position[i]=(a,b)
            direction[i]= mult_tuple(direction[i],(-1,-1))
            
        
        if a<= 0 and b>=1:
            b=1
            a=0
            position[i]=(a,b)
            direction[i]= mult_tuple(direction[i],(-1,-1))
            
            
        if b<= 0 and a>=1:
            a=1
            b=0
            position[i]=(a,b)
            direction[i]= mult_tuple(direction[i],(-1,-1))
            
            
        if a<= 0 and b>0 and b<1:
            a=0
            
            position[i]=(a,b)
            direction[i]= mult_tuple(direction[i],(-1,1))
        
        if a>= 1 and b>0 and b<1:
            a=1
            
            position[i]=(a,b)
            direction[i]= mult_tuple(direction[i],(-1,1))
            
        if b<= 0 and a>0 and a<1:
            b=0
            
            position[i]=(a,b)
            direction[i]= mult_tuple(direction[i],(1,-1))
        
        if b>= 1 and a>0 and a<1:
            b=1
            
            position[i]=(a,b)
            direction[i]= mult_tuple(direction[i],(1,-1))
             
    return N,position, direction

# %%
def fusion_v5(N,position,direction,typ):
    weight_set = set([4,63,40,60,24,83,65,22])
    for i in N:
        for e in N:
            if i!=e:
                (x0,y0)=position[i]
                (x1,y1)=position[e]
                if np.around(x0,1)==np.around(x1,1) and np.around(y0,1)==np.around(y1,1):
                    if typ[i]+typ[e] in weight_set:
                        typ[i]=typ[i]+typ[e]              
                    
                        del typ[e]
                        del position[e]
                        del direction[e]
                        del N[N.index(e)]                        
                            
    return N,position,direction,typ

# %%
t=50
plt.figure()

plt.xlim(0, 1)
plt.ylim(0, 1)

N,position,typ = random_particules_v3(20)

for i in N:
    (a,b)=position[i]
    if typ[i]==2:  #H
        plt.scatter(a,b,c="gray")
    if typ[i]==20:  #O
        plt.scatter(a,b,c="red")
    if typ[i]==43:  #C
        plt.scatter(a,b,c="black")
#plt.savefig("0.png")
plt.show()
        
direction=direction_v3(N,position,0.05)

for i in range(t):
    N,position,direction=update_particules_v3(N,position,direction)
    N,position,direction,typ=fusion_v5(N,position,direction,typ) 
    
    for e in N:
        (a,b)=position[e]
        if typ[e]==2:   #H
            plt.scatter(a,b,c="gray")
        if typ[e]==20:  #O
            plt.scatter(a,b,c="red")
        if typ[e]==43:   #C
            plt.scatter(a,b,c="black")
            
        if typ[e]==4:   #H2
            plt.scatter(a,b,c="gray",s=200)
        if typ[e]==22:  #OH
            plt.scatter(a,b,c="red",s=400,marker='s')
        if typ[e]==65:  #COH
            plt.scatter(a,b,c="red",s=800,marker='s')
            
        if typ[e]==40:   #O2
            plt.scatter(a,b,c="red",s=200)
        if typ[e]==60:   #O3
            plt.scatter(a,b,c="red",s=400)
        if typ[e]==63:  #CO
            plt.scatter(a,b,c="red",s=200,marker='p')
        if typ[e]==83:  #CO2
            plt.scatter(a,b,c="red",s=400,marker='p')
        if typ[e]==24:   #H2O
            plt.scatter(a,b,c="blue",s=400,marker='X')
        

        
    plt.xlim(0, 1)
    plt.ylim(0, 1)    
    #plt.savefig(str(i+1)+".png")
    plt.show()

# %%
t=50



fig = plt.figure()



plt.xlim(0, 1)
plt.ylim(0, 1)

N,position,typ = random_particules_v3(10)

for i in N:
    (a,b)=position[i]
    if typ[i]==2:  #H
        plt.scatter(a,b,c="gray")
    if typ[i]==20:  #O
        plt.scatter(a,b,c="red")
    if typ[i]==43:  #C
        plt.scatter(a,b,c="black")
#plt.savefig("0.png")
plt.show()
        
direction=direction_v3(N,position,0.05)

def animate(i):
    N,position,direction=update_particules_v3(N,position,direction)
    N,position,direction,typ=fusion_v5(N,position,direction,typ) 
    
    for e in N:
        (a,b)=position[e]
        if typ[e]==2:   #H
            plt.scatter(a,b,c="gray")
        if typ[e]==20:  #O
            plt.scatter(a,b,c="red")
        if typ[e]==43:   #C
            plt.scatter(a,b,c="black")
            
        if typ[e]==4:   #H2
            plt.scatter(a,b,c="gray",s=200)
        if typ[e]==22:  #OH
            plt.scatter(a,b,c="red",s=400,marker='s')
        if typ[e]==65:  #COH
            plt.scatter(a,b,c="red",s=800,marker='s')
            
        if typ[e]==40:   #O2
            plt.scatter(a,b,c="red",s=200)
        if typ[e]==60:   #O3
            plt.scatter(a,b,c="red",s=400)
        if typ[e]==63:  #CO
            plt.scatter(a,b,c="red",s=200,marker='p')
        if typ[e]==83:  #CO2
            plt.scatter(a,b,c="red",s=400,marker='p')
        if typ[e]==24:   #H2O
            plt.scatter(a,b,c="blue",s=400,marker='X')
        plt.xlim(0, 1)
        
        
        plt.ylim(0, 1)
        
ani = anim.FuncAnimation(fig, animate, frames=100, blit=True, interval=20, repeat=False)        

plt.show()
# Out:
# Traceback (most recent call last):
#   File "/srv/conda/lib/python3.6/site-packages/matplotlib/cbook/__init__.py", line 215, in process
#     func(*args, **kwargs)
#   File "/srv/conda/lib/python3.6/site-packages/matplotlib/animation.py", line 999, in _start
#     self._init_draw()
#   File "/srv/conda/lib/python3.6/site-packages/matplotlib/animation.py", line 1740, in _init_draw
#     self._draw_frame(next(self.new_frame_seq()))
#   File "/srv/conda/lib/python3.6/site-packages/matplotlib/animation.py", line 1762, in _draw_frame
#     self._drawn_artists = self._func(framedata, *self._args)
#   File "<ipython-input-9-7d538595be7f>", line 28, in animate
#     N,position,direction=update_particules_v3(N,position,direction)
# UnboundLocalError: local variable 'N' referenced before assignment
